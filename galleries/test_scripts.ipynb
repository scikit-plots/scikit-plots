# %% [markdown]
# ## test_scripts.ipynb
#
# `%run`: Python scripts and shows any outputs directly in the notebook.

# %% [markdown]
# ### ../docs/source

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ../docs/source/introduction/quick_start.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ../docs/source/introduction/quick_start_tf.py
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736265825.861673   63511 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736265825.870658   63511 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ### ./examples/calibration

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/calibration/plot_calibration_script.py
