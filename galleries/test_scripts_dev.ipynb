# %% [markdown]
# ## test_scripts.ipynb
#
# `%run`: Python scripts and shows any outputs directly in the notebook.

# %%
# %%time
import scikitplot as sp
dir(sp), sp.__version__
# Out:
# CPU times: user 3.24 s, sys: 240 ms, total: 3.48 s
# Wall time: 4.9 s
# (['LowLevelCallable',
#   'SpLogger',
#   '_BUILT_WITH_MESON',
#   '_Default',
#   '_Deprecated',
#   '_NoValue',
#   '_TYPE_CHECKING',
#   '__all__',
#   '__array_api_version__',
#   '__bibtex__',
#   '__builtins__',
#   '__cached__',
#   '__citation__',
#   '__config__',
#   '__dir__',
#   '__doc__',
#   '__file__',
#   '__getattr__',
#   '__git_hash__',
#   '__loader__',
#   '__name__',
#   '__numpy_version__',
#   '__package__',
#   '__path__',
#   '__spec__',
#   '__version__',
#   '_api',
#   '_astropy',
#   '_build_utils',
#   '_builtins',
#   '_c_internal_utils',
#   '_citation',
#   '_compat',
#   '_config',
#   '_distributor_init',
#   '_docstring',
#   '_externals',
#   '_factory_api',
#   '_globals',
#   '_min_dependencies',
#   '_preprocess',
#   '_seaborn',
#   '_testing',
#   '_tweedie',
#   '_utils',
#   '_xp_core_lib',
#   'api',
#   'cbook',
#   'config_context',
#   'decomposition',
#   'estimators',
#   'get_config',
#   'get_logger',
#   'gpu_libraries',
#   'kds',
#   'metrics',
#   'misc',
#   'modelplotpy',
#   'online_help',
#   'pipeline',
#   'plotters',
#   'probscale',
#   'remove_paths',
#   'set_config',
#   'show_config',
#   'show_versions',
#   'sp_logger',
#   'sp_logging',
#   'stack_mpl_figures',
#   'stats',
#   'test',
#   'typing',
#   'utils',
#   'version',
#   'visualkeras'],
#  '0.4.0rc4')

# %%
# %%time
import scikitplot as sp
sp.__all__, sp.__version__
# Out:
# CPU times: user 143 μs, sys: 12 μs, total: 155 μs
# Wall time: 165 μs
# (('LowLevelCallable',
#   'SpLogger',
#   '_BUILT_WITH_MESON',
#   '_Default',
#   '_Deprecated',
#   '_NoValue',
#   '_TYPE_CHECKING',
#   '__array_api_version__',
#   '__bibtex__',
#   '__builtins__',
#   '__cached__',
#   '__citation__',
#   '__config__',
#   '__doc__',
#   '__file__',
#   '__git_hash__',
#   '__loader__',
#   '__name__',
#   '__numpy_version__',
#   '__package__',
#   '__path__',
#   '__spec__',
#   '__version__',
#   '_api',
#   '_astropy',
#   '_build_utils',
#   '_builtins',
#   '_c_internal_utils',
#   '_citation',
#   '_compat',
#   '_config',
#   '_distributor_init',
#   '_docstring',
#   '_externals',
#   '_factory_api',
#   '_globals',
#   '_min_dependencies',
#   '_preprocess',
#   '_seaborn',
#   '_testing',
#   '_tweedie',
#   '_utils',
#   '_xp_core_lib',
#   'api',
#   'cbook',
#   'config_context',
#   'decomposition',
#   'estimators',
#   'get_config',
#   'get_logger',
#   'gpu_libraries',
#   'kds',
#   'metrics',
#   'misc',
#   'modelplotpy',
#   'pipeline',
#   'plotters',
#   'probscale',
#   'remove_paths',
#   'set_config',
#   'show_config',
#   'show_versions',
#   'sp_logger',
#   'sp_logging',
#   'stack_mpl_figures',
#   'stats',
#   'test',
#   'typing',
#   'utils',
#   'version',
#   'visualkeras'),
#  '0.4.0rc4')

# %% [markdown]
# # Galleries

# %% [markdown]
# ### ./examples/calibration

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/calibration/plot_calibration_script.py
# Out:
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/plot_calibration_20250422_221541Z.png
# [INFO] Plot saved to: /home/jovyan/work/galleries/result_images/plot_calibration_20250422_221541Z.png

# %% [markdown]
# ### ./examples/classification

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_classifier_eval_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_confusion_matrix_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_feature_importances_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_learning_curve_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_precision_recall_script.py
# Out:
# /opt/conda/envs/py311/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_roc_script.py
# Out:
# /opt/conda/envs/py311/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### ./examples/clustering

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/clustering/plot_elbow_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/clustering/plot_silhouette_script.py

# %% [markdown]
# ### ./examples/decomposition

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/decomposition/plot_pca_2d_projection_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/decomposition/plot_pca_component_variance_script.py

# %% [markdown]
# ### ./examples/kds

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/kds/plot_cumulative_gain_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/kds/plot_ks_statistic_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/kds/plot_lift_script.py

# %% [markdown]
# ### ./examples/modelplotpy

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/modelplotpy/plot_modelplotpy_script.py
# Out:
# (41188, 6)
#     y  duration  campaign  pdays  previous  euribor3m
# 0  no       261         1    999         0      4.857
# 1  no       149         1    999         0      4.857
# 2  no       226         1    999         0      4.857
# 3  no       151         1    999         0      4.857
# 4  no       307         1    999         0      4.857
# Default scope value no_comparison selected, single evaluation line will be plotted.
# The label with smallest class is term deposit
# Target class term deposit, dataset test_data and model random_forest.
# When we select 30% with the highest probability according to model random_forest, this selection holds 93% of all term deposit cases in dataset test_data.
# When we select 30% with the highest probability according to model random_forest in dataset test_data, this selection for target class term deposit is 3.13 times than selecting without a model.
# When we select decile 3 from model random_forest in dataset test_data the percentage of term deposit cases in the selection is 13%.
# When we select deciles 1 until 3 according to model random_forest in dataset test_data the percentage of term deposit cases in the selection is 35%.
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/plot_all_20250422_145441Z.png
# [INFO] Plot saved to: /home/jovyan/work/galleries/result_images/plot_all_20250422_145441Z.png
# When we select decile 1 until 3 from model random_forest in dataset test_data the percentage of term deposit cases in the expected expected return on investment is 70%.
# When we select decile 1 until 3 from model random_forest in dataset test_data the percentage of term deposit cases in the revenue is 64950.
# When we select decile 1 until 3 from model random_forest in dataset test_data the percentage of term deposit cases in the expected profit is 26880.
# compare models
# The label with smallest class is ['term deposit']
# When we select deciles 1 until 3 according to model multinomial_logit in dataset test_data the percentage of term deposit cases in the selection is 33%.
# When we select deciles 1 until 3 according to model random_forest in dataset test_data the percentage of term deposit cases in the selection is 35%.

# %% [markdown]
# ### ./examples/regression

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/regression/plot_residuals_distribution_script.py
# Out:
# Fitted mean-mu (μ): -4.4509
# Fitted std (σ)    : 55.2768
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/plot_residuals_distribution_20250422_145618Z.png
# [INFO] Plot saved to: /home/jovyan/work/galleries/result_images/plot_residuals_distribution_20250422_145618Z.png

# %% [markdown]
# ### ./examples/stats

# %% [markdown]
# ### ./examples/visualkeras_ANN

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_ANN/plot_conv_dense.py
# Out:
# 2025-04-22 14:55:50.899764: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-22 14:55:50.956340: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-22 14:55:51.011105: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745333751.066842   45302 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745333751.081414   45302 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745333751.168241   45302 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745333751.168328   45302 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745333751.168331   45302 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745333751.168346   45302 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-22 14:55:51.189350: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-22 14:55:55.281254: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ reshape (Reshape)               │ (None, 100, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 100, 32)        │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 50, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,641 (408.75 KB)
#  Trainable params: 104,641 (408.75 KB)
#  Non-trainable params: 0 (0.00 B)
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/spam_conv_z_20250422_145556Z.png
# [INFO] Image saved using Matplotlib: /home/jovyan/work/galleries/result_images/spam_conv_z_20250422_145556Z.png

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_ANN/plot_dense.py
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                6464
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 8,577
# Trainable params: 8,577
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### ./examples/visualkeras_CNN

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_autoencoder.py
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ img (InputLayer)                │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 6, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 16)       │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 16)             │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 4, 4, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 6, 6, 16)       │           160 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 8, 8, 32)       │         4,640 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 26, 26, 16)     │         4,624 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 28, 28, 1)      │           145 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,241 (110.32 KB)
#  Trainable params: 28,241 (110.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Output shape after running model with dummy input: (1, 28, 28, 1)
# img shape: (None, 28, 28, 1)
# conv2d shape: (None, 26, 26, 16)
# conv2d_1 shape: (None, 24, 24, 32)
# max_pooling2d shape: (None, 8, 8, 32)
# conv2d_2 shape: (None, 6, 6, 32)
# conv2d_3 shape: (None, 4, 4, 16)
# global_max_pooling2d shape: (None, 16)
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/autoencoder_text_20250422_145644Z.png
# [INFO] Image saved using Matplotlib: /home/jovyan/work/galleries/result_images/autoencoder_text_20250422_145644Z.png

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_custom_vgg16_show_dimension.py
# Out:
# 2025-04-22 13:16:26.749166: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2025-04-22 13:16:27.018571: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2025-04-22 13:16:27.877698: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_custom_vgg16.py
# Out:
# 2025-04-22 13:16:59.152492: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2025-04-22 13:16:59.521435: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_efficientnetv2.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_resnetv2.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_vgg.py
# Out:
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/vgg19_20250422_140916Z.png
# [INFO] Image saved using Matplotlib: /home/jovyan/work/galleries/result_images/vgg19_20250422_140916Z.png

# %% [markdown]
# ### ./examples/visualkeras_NLP

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_NLP/plot_nlp_mpnet_with_tf_layers.py
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFMPNetModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing TFMPNetModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFMPNetModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFMPNetModel were not initialized from the PyTorch model and are newly initialized: ['mpnet.pooler.dense.weight', 'mpnet.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_ids         │ (None, 128)     │         0 │ -              │   -   │
# │ (InputLayer)      │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ attention_mask    │ (None, 128)     │         0 │ -              │   -   │
# │ (InputLayer)      │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ microsoft_mpnet-… │ (None, 128,     │         0 │ input_ids[0][… │   -   │
# │ (Lambda)          │ 768)            │           │ attention_mas… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reshape (Reshape) │ (None, 1, 128,  │         0 │ microsoft_mpn… │   -   │
# │                   │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_1 (Conv2D) │ (None, 1, 128,  │ 3,539,456 │ reshape[0][0]  │   Y   │
# │                   │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batchnorm_1       │ (None, 1, 128,  │     2,048 │ conv2d_1[0][0] │   Y   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_1         │ (None, 1, 128,  │         0 │ batchnorm_1[0… │   -   │
# │ (Dropout)         │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ maxpool_1         │ (None, 0, 64,   │         0 │ dropout_1[0][… │   -   │
# │ (MaxPooling2D)    │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_2 (Conv2D) │ (None, 0, 64,   │ 1,179,904 │ maxpool_1[0][… │   Y   │
# │                   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batchnorm_2       │ (None, 0, 64,   │     1,024 │ conv2d_2[0][0] │   Y   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_2         │ (None, 0, 64,   │         0 │ batchnorm_2[0… │   -   │
# │ (Dropout)         │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ maxpool_2         │ (None, 0, 32,   │         0 │ dropout_2[0][… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_3 (Conv2D) │ (None, 0, 32,   │   295,040 │ maxpool_2[0][… │   Y   │
# │                   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batchnorm_3       │ (None, 0, 32,   │       512 │ conv2d_3[0][0] │   Y   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_3         │ (None, 0, 32,   │         0 │ batchnorm_3[0… │   -   │
# │ (Dropout)         │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ maxpool_3         │ (None, 0, 16,   │         0 │ dropout_3[0][… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ globalaveragepool │ (None, 128)     │         0 │ maxpool_3[0][… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_1 (Dense)   │ (None, 512)     │    66,048 │ globalaverage… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_4         │ (None, 512)     │         0 │ dense_1[0][0]  │   -   │
# │ (Dropout)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_2 (Dense)   │ (None, 128)     │    65,664 │ dropout_4[0][… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dummy_classifica… │ (None, 2)       │       258 │ dense_2[0][0]  │   Y   │
# │ (Dense)           │                 │           │                │       │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 5,149,954 (19.65 MB)
#  Trainable params: 5,148,162 (19.64 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# /home/jovyan/work/scikitplot/visualkeras/layered.py:241: UserWarning: The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
#   warnings.warn(
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/nlp_mpnet_with_tf_layers_20250422_141155Z.png
# [INFO] Image saved using Matplotlib: /home/jovyan/work/galleries/result_images/nlp_mpnet_with_tf_layers_20250422_141155Z.png

# %% [markdown]
# # Docs

# %% [markdown]
# ### ../docs/source

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ../docs/source/introduction/quick_start.py
# Out:
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/plot_classifier_eval_20250422_145758Z.png
# [INFO] Plot saved to: /home/jovyan/work/galleries/result_images/plot_classifier_eval_20250422_145758Z.png

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ../docs/source/introduction/quick_start_tf.py
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/plot_precision_recall_20250422_145926Z.png
# [INFO] Plot saved to: /home/jovyan/work/galleries/result_images/plot_precision_recall_20250422_145926Z.png
