# %% [markdown]
# ## test_scripts.ipynb
#
# `%run`: Python scripts and shows any outputs directly in the notebook.

# %%
# %%time
import scikitplot as sp
dir(sp), sp.__version__
# Out:
# CPU times: user 18.9 s, sys: 18.5 s, total: 37.5 s
# Wall time: 45.1 s
# (['LowLevelCallable',
#   '__bibtex__',
#   '__citation__',
#   '__git_hash__',
#   '__numpy_version__',
#   '__version__',
#   'api',
#   'cli',
#   'config',
#   'config_context',
#   'decomposition',
#   'doremi',
#   'environment_variables',
#   'estimators',
#   'exceptions',
#   'experimental',
#   'get_config',
#   'get_logger',
#   'kds',
#   'llm_provider',
#   'logger',
#   'metrics',
#   'misc',
#   'ml_package_versions',
#   'modelplotpy',
#   'online_help',
#   'pipeline',
#   'plot_calibration',
#   'plot_classifier_eval',
#   'plot_confusion_matrix',
#   'plot_elbow',
#   'plot_feature_importances',
#   'plot_learning_curve',
#   'plot_pca_2d_projection',
#   'plot_pca_component_variance',
#   'plot_precision_recall',
#   'plot_precision_recall_curve',
#   'plot_residuals_distribution',
#   'plot_roc',
#   'plot_roc_curve',
#   'plot_silhouette',
#   'plotters',
#   'probscale',
# ...

# %%
# %%time
import scikitplot as sp 

sp.metrics.plot_calibration?
# Out:
# 2025-08-11 07:29:22.174582: I scikitplot 138265819022592 python.py:96:<module>] TOML write support requires `toml` package. Install via `pip install toml`.
# CPU times: user 577 ms, sys: 0 ns, total: 577 ms
# Wall time: 3.25 s
# Signature:
# sp.metrics.plot_calibration(
#     y_true,
#     y_probas_list,
#     *,
#     pos_label=None,
#     class_index=None,
#     class_names=None,
#     to_plot_class_index=1,
#     estimator_names=None,
#     n_bins=10,
#     strategy='uniform',
#     title='Calibration Curves (Reliability Diagrams)',
#     title_fontsize='large',
#     text_fontsize='medium',
#     cmap='inferno',
#     **kwargs,
# )
# Docstring:
# Plot calibration curves for a set of classifier probability estimates.
#
# This function plots calibration curves, also known as reliability curves,
# which are useful to assess the calibration of probabilistic models.
# For a well-calibrated model, the predicted probability should match the
# observed frequency of the positive class.
#
# ...

# %% [markdown]
# # Galleries

# %% [markdown]
# ### ./examples/calibration

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/calibration/plot_calibration_script.py
# Out:
# 2025-08-11 07:29:37.213676: E scikitplot 138265819022592 _calibration.py:318:plot_calibration] 3
# [INFO] Saving path to: /work/notebooks/galleries/result_images/plot_calibration_20250811_072938Z.png
# [INFO] Plot saved to: /work/notebooks/galleries/result_images/plot_calibration_20250811_072938Z.png

# %% [markdown]
# ### ./examples/classification

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_classifier_eval_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_confusion_matrix_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_feature_importances_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_learning_curve_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_precision_recall_script.py
# Out:
# /opt/conda/envs/py311/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_roc_script.py
# Out:
# /opt/conda/envs/py311/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### ./examples/clustering

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/clustering/plot_elbow_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/clustering/plot_silhouette_script.py

# %% [markdown]
# ### ./examples/decomposition

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/decomposition/plot_pca_2d_projection_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/decomposition/plot_pca_component_variance_script.py

# %% [markdown]
# ### ./examples/kds

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/kds/plot_cumulative_gain_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/kds/plot_ks_statistic_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/kds/plot_lift_script.py

# %% [markdown]
# ### ./examples/modelplotpy

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/modelplotpy/plot_modelplotpy_script.py
# Out:
# (41188, 6)
#     y  duration  campaign  pdays  previous  euribor3m
# 0  no       261         1    999         0      4.857
# 1  no       149         1    999         0      4.857
# 2  no       226         1    999         0      4.857
# 3  no       151         1    999         0      4.857
# 4  no       307         1    999         0      4.857
# Default scope value no_comparison selected, single evaluation line will be plotted.
# The label with smallest class is term deposit
# Target class term deposit, dataset test_data and model random_forest.
# When we select 30% with the highest probability according to model random_forest, this selection holds 93% of all term deposit cases in dataset test_data.
# When we select 30% with the highest probability according to model random_forest in dataset test_data, this selection for target class term deposit is 3.13 times than selecting without a model.
# ...

# %% [markdown]
# ### ./examples/regression

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/regression/plot_residuals_distribution_script.py
# Out:
# Fitted mean-mu (μ): -4.4509
# Fitted std (σ)    : 55.2768
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/plot_residuals_distribution_20250625_144733Z.png
# [INFO] Plot saved to: /home/jovyan/work/galleries/result_images/plot_residuals_distribution_20250625_144733Z.png

# %% [markdown]
# ### ./examples/stats

# %% [markdown]
# ### ./examples/visualkeras_ANN

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_ANN/plot_conv_dense.py
# Out:
# 2025-06-23 00:36:09.688052: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-23 00:36:14.772749: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-23 00:36:15.806156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750638976.764665   18490 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750638977.064078   18490 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_ANN/plot_dense.py
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 64)                6464
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# ...
# Total params: 8,577
# Trainable params: 8,577
# Non-trainable params: 0
# _________________________________________________________________
# 2025-06-23 00:36:39.905164: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
# 2025-06-23 00:36:40.153429: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
# ...

# %% [markdown]
# ### ./examples/visualkeras_CNN

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_autoencoder.py
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ img (InputLayer)                │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 6, 32)       │         9,248 │
# ...

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_custom_vgg16_show_dimension.py
# Out:
# 2025-06-23 00:36:47.602293: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2025-06-23 00:36:48.383605: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2025-06-23 00:36:56.676019: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2025-06-23 00:37:28.656198: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
# 2025-06-23 00:37:32.838971: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
# ...

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_custom_vgg16.py
# Out:
# 2025-06-23 00:37:58.357074: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2025-06-23 00:38:02.027340: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2025-06-23 00:39:18.119464: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
# 2025-06-23 00:39:19.774476: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
# 2025-06-23 00:39:21.522094: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
# ...

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_efficientnetv2.py
# Out:
# 2025-06-23 00:40:16.658219: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_resnetv2.py
# Out:
# 2025-06-23 00:40:24.921458: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_vgg.py
# Out:
# 2025-06-23 00:41:21.848147: W scikitplot 126197003428928 layered.py:203:layered_view] The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/vgg19_20250623_004139Z.png

# %% [markdown]
# ### ./examples/visualkeras_NLP

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_NLP/plot_nlp_mpnet_with_tf_layers.py
# Out:
# config.json:   0%|          | 0.00/493 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/532M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFMPNetModel: ['lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing TFMPNetModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFMPNetModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # Docs

# %% [markdown]
# ### ../docs/source

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ../docs/source/introduction/quick_start.py
# Out:
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/plot_classifier_eval_20250623_004844Z.png
# [INFO] Plot saved to: /home/jovyan/work/galleries/result_images/plot_classifier_eval_20250623_004844Z.png

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ../docs/source/introduction/quick_start_tf.py
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# [INFO] Saving path to: /home/jovyan/work/galleries/result_images/plot_precision_recall_20250623_004912Z.png
# [INFO] Plot saved to: /home/jovyan/work/galleries/result_images/plot_precision_recall_20250623_004912Z.png
