# %% [markdown]
# ### An example showing the plot_lift method used by a scikit-learn classifier
#
# In this example, we'll be plotting a `lift` to describe the classifier model performance
# using the **breast_cancer**, **iris** or **digits** dataset from scikit-learn.
# - `LogisticRegression`
# - `RandomForestClassifier`
#
# Here, we'll be using the `scikitplot.deciles.plot_lift` method.

# %%
from sklearn.datasets import load_breast_cancer as data_2_classes
from sklearn.datasets import load_iris as data_3_classes
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

import numpy as np
np.random.seed(0)
# importing pylab or pyplot
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 5)

# Import scikit-plot
import scikitplot as sp

sp.__version__
# Out:
# '0.4.0.post9'

# %%
from scikitplot.decile import kds
# Out:
# 2026-01-22 05:58:06.716247: W scikitplot._docstrings._docstring 130441550607616 _docstring.py:407:__call__] Docstring substitution failed for <function plot_response at 0x76a25f767380>: must be real number, not dict
# 2026-01-22 05:58:06.717676: W scikitplot._docstrings._docstring 130441550607616 _docstring.py:407:__call__] Docstring substitution failed for <function plot_cumresponse at 0x76a25f767420>: must be real number, not dict
# 2026-01-22 05:58:06.718784: W scikitplot._docstrings._docstring 130441550607616 _docstring.py:407:__call__] Docstring substitution failed for <function plot_cumgains at 0x76a25f767880>: must be real number, not dict
# 2026-01-22 05:58:06.720095: W scikitplot._docstrings._docstring 130441550607616 _docstring.py:407:__call__] Docstring substitution failed for <function plot_all at 0x76a25f7679c0>: must be real number, not dict
# ...

# %%
kds.plot_lift?
# Out:
# Signature:
# kds.plot_lift(
#     y_true,
#     y_score,
#     *,
#     pos_label=None,
#     class_index=1,
#     title='Lift Curves',
#     title_fontsize='large',
#     text_fontsize='medium',
#     data=None,
#     **kwargs,
# )
# Docstring:
# Generate the Decile based cumulative Lift Plot from labels and probabilities.
#
# .. dropdown:: View aliases
#
#     **Main aliases**
#
#     `scikitplot.api.kds.plot_lift`
#
#     **Compat aliases**
#
#     `scikitplot.decile.kds.plot_lift`
#
# The lift curve is used to determine the effectiveness of a
# binary classifier. A detailed explanation can be found at
# http://www2.cs.uregina.ca/~dbd/cs831/notes/lift_chart/lift_chart.html
# The implementation here works only for binary classification.
#
# Parameters
# ----------
# y_true : array-like of shape (n_samples,)
#     Ground truth (correct) target values.
#
# y_score : array-like of shape (n_samples,) or (n_samples, n_classes)
# ...

# %%
# Load the data
X, y = data_2_classes(return_X_y=True, as_frame=False)
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.5, random_state=0
)

# %%
# Create an instance of the LogisticRegression
model = (
    LogisticRegression(max_iter=int(1e5), random_state=0)
    .fit(X_train, y_train)
)

# Perform predictions
y_val_prob = model.predict_proba(X_val)

# Plot!
ax = kds.plot_lift(
    y_val, y_val_prob,
)

# %%
# Load the data
X, y = data_3_classes(return_X_y=True, as_frame=False)
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.5, random_state=0
)

# %%
# Create an instance of the LogisticRegression
model = (
    LogisticRegression(max_iter=int(1e5), random_state=0)
    .fit(X_train, y_train)
)

# Perform predictions
y_val_prob = model.predict_proba(X_val)

# Plot!
ax = kds.plot_lift(
    y_val, y_val_prob,
	plot_style='ggplot',
)
