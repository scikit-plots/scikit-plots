# %%
import scikitplot as sp

sp.__version_iso_8601__
# Out:
# '2026.01.29'

# %%
print(sp._logo._SCIKITPLOT_BANNER)
# Out:
# ____       _ _    _ _              _       _
# / ___|  ___(_) | _(_) |_      _ __ | | ___ | |_ ___
# \___ \ / __| | |/ / | __|____| '_ \| |/ _ \| __/ __|
#  ___) | (__| |   <| | ||_____| |_) | | (_) | |_\__ \
# |____/ \___|_|_|\_\_|\__|    | .__/|_|\___/ \__|___/
#                              |_|

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# %%
from scikitplot import cython

cython?

# %%
python -c 'from scikitplot import cython;cython.generate_sphinx_template_docs("./")'

# %%
>>> from scikitplot.cython import compile_and_load
>>> m = compile_and_load("def f(int n):\n    return n*n")
>>> m.f(10)

# %%
>>> from scikitplot.cython import compile_template
>>> m = compile_template('basic_cython/t01_square_int')
>>> m.square(12)

# %%
from scikitplot.cython import compile_template, list_templates, read_template

list_templates()

# %%
print(read_template(list_templates()[0]))

# %%
name = list_templates()[0]
m = compile_template(name, verbose=1)
print(f"Compiled: {name} -> module={{m.__name__}}")
# If the template defines a known demo entrypoint, call it deterministically.
m

# %%
dir(m)

# %%
m?

# %%
m.square(2)
