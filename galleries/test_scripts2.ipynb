# %% [markdown]
# ## test_scripts.ipynb
#
# `%run`: Python scripts and shows any outputs directly in the notebook.

# %% [markdown]
# ### ../docs/source

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ../docs/source/introduction/quick_start.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ../docs/source/introduction/quick_start_tf.py
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %% [markdown]
# ### ./examples/calibration

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/calibration/plot_calibration_script.py

# %% [markdown]
# ### ./examples/classification

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_feature_importances_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_precision_recall_script.py

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/classification/plot_roc_script.py

# %% [markdown]
# ### ./examples/clustering

# %% [markdown]
# ### ./examples/decomposition

# %% [markdown]
# ### ./examples/kds

# %% [markdown]
# ### ./examples/modelplotpy

# %% [markdown]
# ### ./examples/regression

# %% [markdown]
# ### ./examples/stats

# %% [markdown]
# ### ./examples/visualkeras_ANN

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_ANN/plot_conv_dense.py
# Out:
# /opt/conda/envs/py311/lib/python3.11/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Image saved using Matplotlib: ../result_images/spam_conv.png

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_ANN/plot_dense.py
# Out:
# Image saved using Matplotlib: ../result_images/spam_dense.png

# %% [markdown]
# ### ./examples/visualkeras_CNN

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_autoencoder.py
# Out:
# Output shape after running model with dummy input: (1, 28, 28, 1)
# img shape: (None, 28, 28, 1)
# conv2d shape: (None, 26, 26, 16)
# conv2d_1 shape: (None, 24, 24, 32)
# max_pooling2d shape: (None, 8, 8, 32)
# conv2d_2 shape: (None, 6, 6, 32)
# conv2d_3 shape: (None, 4, 4, 16)
# global_max_pooling2d shape: (None, 16)
# Image saved using Matplotlib: ../result_images/encoder.png
# Image saved using Matplotlib: ../result_images/autoencoder.png
# Image saved using Matplotlib: ../result_images/autoencoder_text.png

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_CNN/plot_custom_vgg16_show_dimension.py
# Out:
# 2025-04-19 21:17:34.554999: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-19 21:17:34.592966: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-19 21:17:34.920596: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-19 21:17:35.086738: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745097455.564128   25645 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745097455.787148   25645 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745097456.474323   25645 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745097456.474361   25645 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745097456.474365   25645 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745097456.474367   25645 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-19 21:17:36.540917: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-19 21:17:48.837394: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Font not found, using default font.
# /workspaces/scikit-plots/scikitplot/visualkeras/layered.py:144: UserWarning: The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
#   warnings.warn(
# Image saved using Matplotlib: ../result_images/vgg16_show_dimension.png
# Image saved using Matplotlib: ../result_images/vgg16_legend_show_dimension.png
# Image saved using Matplotlib: ../result_images/vgg16_spacing_layers_show_dimension.png
# Image saved using Matplotlib: ../result_images/vgg16_type_ignore_show_dimension.png
# Image saved using Matplotlib: ../result_images/vgg16_color_map_show_dimension.png
# Image saved using Matplotlib: ../result_images/vgg16_flat_show_dimension.png
# Image saved using Matplotlib: ../result_images/vgg16_scaling_show_dimension.png

# %% [markdown]
# ### ./examples/visualkeras_NLP

# %%
# %run: Python scripts and shows any outputs directly in the notebook.
# %run ./examples/visualkeras_NLP/plot_nlp_mpnet_with_tf_layers.py
# Out:
# 2025-04-19 21:18:50.521843: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-19 21:18:50.624787: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-19 21:18:51.249931: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-19 21:18:51.612800: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745097532.011741   26074 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745097532.165480   26074 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745097532.954377   26074 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745097532.954409   26074 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745097532.954411   26074 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745097532.954413   26074 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-19 21:18:53.143860: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-19 21:19:20.304418: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFMPNetModel: ['lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias']
# - This IS expected if you are initializing TFMPNetModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFMPNetModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFMPNetModel were not initialized from the PyTorch model and are newly initialized: ['mpnet.pooler.dense.weight', 'mpnet.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_ids         │ (None, 128)     │         0 │ -              │   -   │
# │ (InputLayer)      │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ attention_mask    │ (None, 128)     │         0 │ -              │   -   │
# │ (InputLayer)      │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ microsoft_mpnet-… │ (None, 128,     │         0 │ input_ids[0][… │   -   │
# │ (Lambda)          │ 768)            │           │ attention_mas… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reshape (Reshape) │ (None, 1, 128,  │         0 │ microsoft_mpn… │   -   │
# │                   │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_1 (Conv2D) │ (None, 1, 128,  │ 3,539,456 │ reshape[0][0]  │   Y   │
# │                   │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batchnorm_1       │ (None, 1, 128,  │     2,048 │ conv2d_1[0][0] │   Y   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_1         │ (None, 1, 128,  │         0 │ batchnorm_1[0… │   -   │
# │ (Dropout)         │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ maxpool_1         │ (None, 0, 64,   │         0 │ dropout_1[0][… │   -   │
# │ (MaxPooling2D)    │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_2 (Conv2D) │ (None, 0, 64,   │ 1,179,904 │ maxpool_1[0][… │   Y   │
# │                   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batchnorm_2       │ (None, 0, 64,   │     1,024 │ conv2d_2[0][0] │   Y   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_2         │ (None, 0, 64,   │         0 │ batchnorm_2[0… │   -   │
# │ (Dropout)         │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ maxpool_2         │ (None, 0, 32,   │         0 │ dropout_2[0][… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_3 (Conv2D) │ (None, 0, 32,   │   295,040 │ maxpool_2[0][… │   Y   │
# │                   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batchnorm_3       │ (None, 0, 32,   │       512 │ conv2d_3[0][0] │   Y   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_3         │ (None, 0, 32,   │         0 │ batchnorm_3[0… │   -   │
# │ (Dropout)         │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ maxpool_3         │ (None, 0, 16,   │         0 │ dropout_3[0][… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ globalaveragepool │ (None, 128)     │         0 │ maxpool_3[0][… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_1 (Dense)   │ (None, 512)     │    66,048 │ globalaverage… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_4         │ (None, 512)     │         0 │ dense_1[0][0]  │   -   │
# │ (Dropout)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_2 (Dense)   │ (None, 128)     │    65,664 │ dropout_4[0][… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dummy_classifica… │ (None, 2)       │       258 │ dense_2[0][0]  │   Y   │
# │ (Dense)           │                 │           │                │       │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 5,149,954 (19.65 MB)
#  Trainable params: 5,148,162 (19.64 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# /workspaces/scikit-plots/scikitplot/visualkeras/layered.py:144: UserWarning: The legend_text_spacing_offset parameter is deprecated andwill be removed in a future release.
#   warnings.warn(
# Image saved using Matplotlib: ../result_images/nlp_mpnet_with_tf_layers.png
